# %%
import kagglehub

# %%
kagglehub.login()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\codes\march_mania\march_mania\venv\lib\site-packages\kagglehub\auth.py:76, in _notebook_login(validate_credentials)
#      75     from IPython.display import display  # type: ignore # noqa: PLC0415
# ---> 76     from ipywidgets import widgets  # type: ignore # noqa: PLC0415
#      77 except ImportError:
#
# ModuleNotFoundError: No module named 'ipywidgets'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 kagglehub.login()
#
# File d:\codes\march_mania\march_mania\venv\lib\site-packages\kagglehub\auth.py:145, in login(validate_credentials)
#     142 """Prompt the user for their Kaggle API token and save it globally."""
#     144 if _is_in_notebook():
# ...

# %%
import sys; print(sys.executable)
# Out:
# d:\codes\march_mania\march_mania\venv\Scripts\python.exe
